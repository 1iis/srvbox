# %%
# %%html
# <style>
#
# /* ── Variables ── */
# :root {
#     --font-sans: sans-serif;
#     --font-mono: monospace;
#
#     --font-size: 1.17rem;
#     --code-letter-spacing: -0.03rem;
#     --font-weight: 400;
#     --quote-weight: 300;
#     --border-thin: 1px;
#     --border-card: 1.5px;
#     --border-thick: 7px;
#
#     --color-foreground: hsla(0, 0%, 0%, 1.00);
#     --color-muted-foreground: hsla(0, 0%, 0%, 0.7);
#
#     --color-background: hsla(48, 21%, 89%, 1.00);
#     --color-muted-background: hsla(46, 21%, 86%, 1.00);
#
#     --muted-foreground: hsla(0, 0%, 0%, 0.35);
#     --mute-background: hsla(0, 0%, 0%, 0.12);
#
#     --color-title: hsla(0, 0%, 0%, 1.00);
#     --color-accent1: hsla(47, 11%, 33%, 1.00);
#     --color-accent2: hsla(162, 100%, 27%, 1.00);
#     --color-accent3: hsla(248, 100%, 42%, 1.00);
#     --color-accent4:hsla(338, 100%, 62%, 1.00);
#     --color-accent5: hsla(230, 52%, 42%, 1.00);
#
#     --color-cell-prompt: hsla(0, 0%, 0%, 1.00);
#     --color-cell-raw: hsla(0, 0%, 0%, 1.00);
#     --color-cell-note: hsla(145, 63%, 49%, 0);
#     --color-cell-code: hsla(212, 72%, 59%, 0);
#     --color-code: var(--color-accent5);
# }
#
# :root.dark {
#     --color-foreground: hsla(0, 0%, 100%, 1.00);
#     --color-muted-foreground: hsla(0, 100%, 100%, 0.45);
#
#     --color-background:       hsla(0, 0%, 00%, 1);
#     --color-muted-background: hsla(0, 0%, 12%, 1);
#
#     --muted-foreground: hsla(0, 0%, 100%, 0.35);
#     --mute-background: hsla(0, 0%, 100%, 0.3);
#
#     --color-title: hsla(48, 22%, 77%, 1.00);
#     --color-accent1: hsla(48, 42%, 82%, 1.00);
#     --color-accent2: hsla(162, 100%, 50%, 1.00);
#     --color-accent3: hsla(248, 100%, 82%, 1.00);
#     --color-accent4:hsla(338, 100%, 62%, 1.00);
#     --color-accent5: hsla(230, 100%, 80%, 1.00);
#     --color-muted-accent1: hsla(49, 41%, 82%, 0.5);
#
#     --color-cell-prompt: var(--color-accent1);
#     --color-cell-raw: var(--color-accent1);
#     --color-cell-note: hsla(145, 63%, 49%, 0);
#     --color-cell-code: hsla(212, 72%, 59%, 0);
#     --color-code: hsla(149, 100%, 84%, 1.00);
#     --color-code: var(--color-accent5);
#
# }
#
# body {
#     font-family: var(--font-sans);
#     font-size: var(--font-size);
#     font-weight: var(--font-weight);
# }
#
# #dialog-container {
#     border-color: var(--color-background);
# }
#
# div.msg-card {
#     border-left-width: var(--border-thin) !important;
# }
#
# pre {
#     padding: 0.3rem 1rem !important;
#     font-weight: 400;
# }
#
# .msg-content pre {
#     background: var(--color-muted-background);
# }
#
# code {
#     color: var(--color-foreground);
#     font-family: var(--font-mono);
#     font-size: calc( var(--font-size) * 0.93 );
# }
#
# .msg-content p code, .msg-content li code, .msg-content table code { background: transparent; }
# :is(h1) code { font-size: inherit; font-weight: 800; }
# :is(h2) code { font-size: inherit; font-weight: 700; }
# :is(h3) code { font-size: inherit; }
# :is(h4, h5, h6) code { font-size: inherit; }
#
# .prose :not(pre, h1, h2, h3, h4, h5, h6)>code {
#     padding: 0;
#     font-size: var(--font-size);
#     font-weight: var(--font-weight);
#     letter-spacing: var(--code-letter-spacing);
# }
#
# .prose :not(pre)>code {
#     color: var(--color-code);
#     background: transparent;
#     padding: 0;
# }
#
# .prose h1,h2,h3,h4,h5,h6 {
#     color: var(--color-title);
#     border-color: var(--color-title);
#     border-style: solid;
# }
#
# .prose h1 {
#     font-size: 3rem;
#     text-align: center;
#     margin: 20px 0 0px;
#     padding: 12px 0;
#     border-width: var(--border-thick) 0px var(--border-thick) 0px;
# }
#
# .prose h2 {
#     font-size: 2.25rem;
#     border-width: 0px 0px var(--border-thin) 0px;
# }
#
# .prose h3 {
#     font-size: 1.5rem;
# }
#
# .prose h4 {
#     font-size: 1.25rem;
# }
#
# .prose h5 {
#     font-size: 1.1rem;
# }
#
# .prose h6 {
#     font-size: 1rem;
# }
#
# #dialog-container {
#     background: transparent;
# }
#
# .uk-card {
#     background: var(--color-background);
#     border-color: transparent;
#     box-shadow: transparent;
# }
#
# .uk-card-header p {
#     color: var(--muted-foreground) !important;
# }
#
# div[data-sm-header="collapsed"] .uk-card-header p {
#     color: var(--color-accent4) !important;
# }
#
# nav .uk-btn {
#     color: var(--muted-foreground);
# }
#
# nav .uk-btn-group {
#     padding-right: 25px;
# }
#
# nav .uk-btn-group button {
#     color: var(--color-accent1);
# }
#
# nav button[title="Expand heading"].uk-btn {
#     color: var(--color-accent4);
# }
#
# div[data-sm-header="collapsed"] * {
#     color: var(--color-muted-foreground);
# }
#
# div[data-icons-vis] button {
#     color: var(--color-background);
# }
#
# div[data-icons-vis] .uk-btn-group:hover button {
#     color: var(--color-accent1);
# }
#
# button[title="Toggle AI visibility (h)"] {
#     position: absolute;
#     right: 0;
# }
#
# .token-usage-details {
#     color: var(--muted-foreground);
# }
#
# .msg-body {
#     padding: var(--spacing) calc(var(--spacing) * 2.6);
# }
#
# .msg-card {
#     background: var(--color-background);
#     box-shadow: None;
# }
#
# .prose p {
#     color: var(--color-foreground);
#     font-size: var(--font-size);
# }
#
# .prose li {
#     color: var(--color-foreground);
#     font-size: var(--font-size);
# }
#
# .prose
# ol>li::marker,
# ul>li::marker {
#     color: var(--color-accent1);
# }
#
# .prose table {
#     font-size: var(--font-size);
# }
#
# .prose thead {    border-bottom: var(--border-thin) solid var(--color-accent1); }
# .prose thead th { color: var(--color-accent1); }
# .prose tbody tr { border-bottom: var(--border-thin) solid var(--color-muted-foreground); }
#
# .prose blockquote {
#     font-style: normal;
#     font-weight: var(--quote-weight);
#     margin: 0;
#     padding: 0.1rem 1rem;
#     border-width: 0px 0px 0px 1px;
#     border-style: solid;
#     border-color: var(--color-accent1);
# }
#
# .prose h1+blockquote {
#     border-width: 0;
# }
#
# .prose blockquote * {
#     color: var(--color-accent1);
# }
#
# div.monaco-editor-background { background: var(--color-muted-background); }
# div.margin { background: var(--color-muted-background) !important; }
# div.view-line { font-family: var(--font-mono); }
#
# .hl-constructor, .hl-function, .hl-function-method {
#     color: var(--color-accent2);
# }
#
# .bg-muted {
#     color: var(--muted-foreground);
#     background: inherit;
# }
#
# .msg-card[data-mtype="prompt"] {
#     border-left-color: var(--color-cell-prompt) !important;
#  }
#
# .msg-card[data-mtype="raw"] {
#     border-left-color: var(--color-cell-raw) !important;
#     border-left-width: var(--border-thick) !important;
#  }
#
# .msg-card[data-mtype="note"] {
#     border-left-color: var(--color-cell-note) !important;
#  }
#
# .msg-card[data-mtype="code"] {
#     border-left-color: var(--color-cell-code) !important;
#  }
#
# .editable[data-sm=primary]
# {
#     --tw-ring-color: var(--color-muted-accent1) !important;
#     border-radius: 0px;
#
# }
# .editable[data-editing] {
#     outline-color: var(--color-accent4);
# }
#
# </style>
# Out:
# HTML(<style>
#
# /* ── Variables ── */
# :root {
#     --font-sans: sans-serif;
#     --font-mono: monospace;
#
#     --font-size: 1.17rem;
#     --code-letter-spacing: -0.03rem;
#     --font-weight: 400;
#     --quote-weight: 300;
#     --border-thin: 1px;
#     --border-card: 1.5px;
#     --border-thick: 7px;
#
#     --color-foreground: hsla(0, 0%, 0%, 1.00);
#     --color-muted-foreground: hsla(0, 0%, 0%, 0.7);
#
#     --color-background: hsla(48, 21%, 89%, 1.00);
#     --color-muted-background: hsla(46, 21%, 86%, 1.00);
#
#     --muted-foreground: hsla(0, 0%, 0%, 0.35);
#     --mute-background: hsla(0, 0%, 0%, 0.12);
#
#     --color-title: hsla(0, 0%, 0%, 1.00);
#     --color-accent1: hsla(47, 11%, 33%, 1.00);
#     --color-accent2: hsla(162, 100%, 27%, 1.00);
#     --color-accent3: hsla(248, 100%, 42%, 1.00);
#     --color-accent4:hsla(338, 100%, 62%, 1.00);
#     --color-accent5: hsla(230, 52%, 42%, 1.00);
#
#     --color-cell-prompt: hsla(0, 0%, 0%, 1.00);
#     --color-cell-raw: hsla(0, 0%, 0%, 1.00);
#     --color-cell-note: hsla(145, 63%, 49%, 0);
#     --color-cell-code: hsla(212, 72%, 59%, 0);
#     --color-code: var(--color-accent5);
# }
#
# :root.dark {
#     --color-foreground: hsla(0, 0%, 100%, 1.00);
#     --color-muted-foreground: hsla(0, 100%, 100%, 0.45);
#
#     --color-background:       hsla(0, 0%, 00%, 1);
#     --color-muted-background: hsla(0, 0%, 12%, 1);
#
#     --muted-foreground: hsla(0, 0%, 100%, 0.35);
#     --mute-background: hsla(0, 0%, 100%, 0.3);
#
#     --color-title: hsla(48, 22%, 77%, 1.00);
#     --color-accent1: hsla(48, 42%, 82%, 1.00);
#     --color-accent2: hsla(162, 100%, 50%, 1.00);
#     --color-accent3: hsla(248, 100%, 82%, 1.00);
#     --color-accent4:hsla(338, 100%, 62%, 1.00);
#     --color-accent5: hsla(230, 100%, 80%, 1.00);
#     --color-muted-accent1: hsla(49, 41%, 82%, 0.5);
#
#     --color-cell-prompt: var(--color-accent1);
#     --color-cell-raw: var(--color-accent1);
#     --color-cell-note: hsla(145, 63%, 49%, 0);
#     --color-cell-code: hsla(212, 72%, 59%, 0);
#     --color-code: hsla(149, 100%, 84%, 1.00);
#     --color-code: var(--color-accent5);
#
# }
#
# body {
#     font-family: var(--font-sans);
#     font-size: var(--font-size);
#     font-weight: var(--font-weight);
# }
#
# #dialog-container {
#     border-color: var(--color-background);
# }
#
# div.msg-card {
#     border-left-width: var(--border-thin) !important;
# }
#
# pre {
#     padding: 0.3rem 1rem !important;
#     font-weight: 400;
# }
#
# .msg-content pre {
#     background: var(--color-muted-background);
# }
#
# code {
#     color: var(--color-foreground);
#     font-family: var(--font-mono);
#     font-size: calc( var(--font-size) * 0.93 );
# }
#
# .msg-content p code, .msg-content li code, .msg-content table code { background: transparent; }
# :is(h1) code { font-size: inherit; font-weight: 800; }
# :is(h2) code { font-size: inherit; font-weight: 700; }
# :is(h3) code { font-size: inherit; }
# :is(h4, h5, h6) code { font-size: inherit; }
#
# .prose :not(pre, h1, h2, h3, h4, h5, h6)>code {
#     padding: 0;
#     font-size: var(--font-size);
#     font-weight: var(--font-weight);
#     letter-spacing: var(--code-letter-spacing);
# }
#
# .prose :not(pre)>code {
#     color: var(--color-code);
#     background: transparent;
#     padding: 0;
# }
#
# .prose h1,h2,h3,h4,h5,h6 {
#     color: var(--color-title);
#     border-color: var(--color-title);
#     border-style: solid;
# }
#
# .prose h1 {
#     font-size: 3rem;
#     text-align: center;
#     margin: 20px 0 0px;
#     padding: 12px 0;
#     border-width: var(--border-thick) 0px var(--border-thick) 0px;
# }
#
# .prose h2 {
#     font-size: 2.25rem;
#     border-width: 0px 0px var(--border-thin) 0px;
# }
#
# .prose h3 {
#     font-size: 1.5rem;
# }
#
# .prose h4 {
#     font-size: 1.25rem;
# }
#
# .prose h5 {
#     font-size: 1.1rem;
# }
#
# .prose h6 {
#     font-size: 1rem;
# }
#
# #dialog-container {
#     background: transparent;
# }
#
# .uk-card {
#     background: var(--color-background);
#     border-color: transparent;
#     box-shadow: transparent;
# }
#
# .uk-card-header p {
#     color: var(--muted-foreground) !important;
# }
#
# div[data-sm-header="collapsed"] .uk-card-header p {
#     color: var(--color-accent4) !important;
# }
#
# nav .uk-btn {
#     color: var(--muted-foreground);
# }
#
# nav .uk-btn-group {
#     padding-right: 25px;
# }
#
# nav .uk-btn-group button {
#     color: var(--color-accent1);
# }
#
# nav button[title="Expand heading"].uk-btn {
#     color: var(--color-accent4);
# }
#
# div[data-sm-header="collapsed"] * {
#     color: var(--color-muted-foreground);
# }
#
# div[data-icons-vis] button {
#     color: var(--color-background);
# }
#
# div[data-icons-vis] .uk-btn-group:hover button {
#     color: var(--color-accent1);
# }
#
# button[title="Toggle AI visibility (h)"] {
#     position: absolute;
#     right: 0;
# }
#
# .token-usage-details {
#     color: var(--muted-foreground);
# }
#
# .msg-body {
#     padding: var(--spacing) calc(var(--spacing) * 2.6);
# }
#
# .msg-card {
#     background: var(--color-background);
#     box-shadow: None;
# }
#
# .prose p {
#     color: var(--color-foreground);
#     font-size: var(--font-size);
# }
#
# .prose li {
#     color: var(--color-foreground);
#     font-size: var(--font-size);
# }
#
# .prose
# ol>li::marker,
# ul>li::marker {
#     color: var(--color-accent1);
# }
#
# .prose table {
#     font-size: var(--font-size);
# }
#
# .prose thead {    border-bottom: var(--border-thin) solid var(--color-accent1); }
# .prose thead th { color: var(--color-accent1); }
# .prose tbody tr { border-bottom: var(--border-thin) solid var(--color-muted-foreground); }
#
# .prose blockquote {
#     font-style: normal;
#     font-weight: var(--quote-weight);
#     margin: 0;
#     padding: 0.1rem 1rem;
#     border-width: 0px 0px 0px 1px;
#     border-style: solid;
#     border-color: var(--color-accent1);
# }
#
# .prose h1+blockquote {
#     border-width: 0;
# }
#
# .prose blockquote * {
#     color: var(--color-accent1);
# }
#
# div.monaco-editor-background { background: var(--color-muted-background); }
# div.margin { background: var(--color-muted-background) !important; }
# div.view-line { font-family: var(--font-mono); }
#
# .hl-constructor, .hl-function, .hl-function-method {
#     color: var(--color-accent2);
# }
#
# .bg-muted {
#     color: var(--muted-foreground);
#     background: inherit;
# }
#
# .msg-card[data-mtype="prompt"] {
#     border-left-color: var(--color-cell-prompt) !important;
#  }
#
# .msg-card[data-mtype="raw"] {
#     border-left-color: var(--color-cell-raw) !important;
#     border-left-width: var(--border-thick) !important;
#  }
#
# .msg-card[data-mtype="note"] {
#     border-left-color: var(--color-cell-note) !important;
#  }
#
# .msg-card[data-mtype="code"] {
#     border-left-color: var(--color-cell-code) !important;
#  }
#
# .editable[data-sm=primary]
# {
#     --tw-ring-color: var(--color-muted-accent1) !important;
#     border-radius: 0px;
#
# }
# .editable[data-editing] {
#     outline-color: var(--color-accent4);
# }
#
# </style>
# )

# %% [markdown]
# # ` sync `
# > `1iis/srvbox/host/sync.ipynb` → `sync.py` source

# %% [markdown]
# ## Imports and constants

# %% [markdown]
# [`sync.py`](file_editor_?fp=%2Fapp%2Fdata%2F1iis%2Fsrvbox%2Fhost%2Fsync.py) starts with stdlib-only imports and a repository root constant. The MVP should stay dependency-free so a fresh Ubuntu/Debian host can run it as soon as `python3` exists.

# %%
#| export
from __future__ import annotations
import argparse
import os
import platform
import pwd
import shutil
import subprocess
import sys
import time
from dataclasses import dataclass
from pathlib import Path
from typing import Callable

# %%
#| export
ROOT = Path(__file__).resolve().parents[1]

# %% [markdown]
# ## Small logging and command helpers

# %% [markdown]
# Keep process helpers tiny and explicit. `log` gives predictable operator output; `run` centralizes subprocess execution so later reconciliation steps can be readable and auditable.

# %%
#| export
def log(msg: str) -> None:
    print(f"==> {msg}")

# %%
#| export
def run(cmd: list[str], *, check: bool = True) -> subprocess.CompletedProcess[str]:
    log("$ " + " ".join(cmd))
    return subprocess.run(cmd, check=check, text=True)

# %% [markdown]
# ## Guard rails

# %% [markdown]
# `apply` is allowed to change the host, so it must run as root and only on the supported OS family. `status` stays cheap and non-root so we can run it locally and in smoke tests.

# %%
#| export
def require_root() -> None:
    if os.geteuid() != 0:
        raise SystemExit("error: sync.py must run as root")

# %%
#| export
def require_ubuntuish() -> None:
    if not Path("/etc/os-release").exists():
        raise SystemExit("error: /etc/os-release not found")

    data = Path("/etc/os-release").read_text()
    if "Ubuntu" not in data and "Debian" not in data:
        raise SystemExit("error: only Ubuntu/Debian-like hosts are supported for now")

# %% [markdown]
# ## Step model

# %% [markdown]
# The MVP uses a tiny `Step` dataclass instead of a framework. Each step has a human-readable name and a nullary function. This keeps the reconciler easy to extend while preserving a clear execution order.

# %%
#| export
@dataclass(frozen=True)
class Step:
    name: str
    fn: Callable[[], None]

# %% [markdown]
# ## Host reconciliation steps

# %% [markdown]
# Each function below is one idempotent host operation. Identity is policy-only for MVP: `srvbox` assumes human deploy users already exist, runs as root when reconciling the host, and defers app-specific system users until concrete apps require them.

# %%
#| export
def ensure_base_dirs() -> None:
    for path in [
        Path("/opt/1iis"),
        Path("/etc/1iis"),
        Path("/var/lib/1iis"),
        Path("/var/log/1iis"),
    ]:
        path.mkdir(parents=True, exist_ok=True)
        shutil.chown(path, user="root", group="root")
        path.chmod(0o755)
        log(f"ensured directory: {path}")

# %%
#| export
def check_access_policy() -> None:
    facts = [
        ("human users",        "unmanaged by srvbox; deploy user must already exist"),
        ("deploy access",      "pre-existing SSH user with sudo"),
        ("privilege",          "satisfied: apply is running as root"),
        ("srvbox user",        "not created; srvbox is a root-run reconciler, not a daemon"),
        ("future app users",   "per-app system users named iis-<app>, created by app deployment when needed"),
    ]

    for key, value in facts: log(f"{key}: {value}")

# %% [markdown]
# ## SSH hardening
#
# SSH is managed through a narrow drop-in under `/etc/ssh/sshd_config.d/`, leaving the vendor/default config intact.
#
# The managed policy keeps the current port and user allow-list outside `srvbox`, while enforcing production red lines: no root login, no password login, no empty passwords, no keyboard-interactive login, public-key auth enabled, PAM preserved, and X11 forwarding disabled.
#
# Before reloading SSH, `srvbox` writes the candidate drop-in, validates the complete OpenSSH configuration with `sshd -t`, and rolls back the file if validation fails.

# %%
#| export
SSHD_DROPIN = Path("/etc/ssh/sshd_config.d/90-1iis-srvbox.conf")

# %%
#| export
SSHD_DROPIN_TEXT = """\
# Managed by srvbox. Local changes may be overwritten.

PermitRootLogin no
PubkeyAuthentication yes
PasswordAuthentication no
PermitEmptyPasswords no
KbdInteractiveAuthentication no
ChallengeResponseAuthentication no
UsePAM yes
X11Forwarding no
"""

# %% [markdown]
# ### File and service helpers
#
# These helpers keep reconciliation steps small: write files only when content changes, preserve ownership/mode explicitly, and route service changes through `systemctl` when available.

# %%
#| export
def write_text_if_changed(path: Path, text: str) -> bool:
    if read_text(path) == text: return False
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(text)
    return True

# %%
#| export
def chown_root(path: Path) -> None: shutil.chown(path, user="root", group="root")

# %%
#| export
def chmod(path: Path, mode: int) -> None: path.chmod(mode)

# %%
#| export
def systemctl(*args: str, check: bool = True) -> subprocess.CompletedProcess[str]:
    return run(["systemctl", *args], check=check)

# %%
#| export
def ssh_service_name() -> str:
    if service_is_active("ssh") != "unknown" or service_is_enabled("ssh") != "unknown": return "ssh"
    if service_is_active("sshd") != "unknown" or service_is_enabled("sshd") != "unknown": return "sshd"
    return "ssh"

# %% [markdown]
# ### SSH validation and rollback
#
# The OpenSSH daemon must accept the full effective configuration before `srvbox` reloads the service. If the candidate drop-in is invalid, the previous managed file is restored.

# %%
#| export
def validate_sshd_config() -> None:
    if not cmd_exists("sshd"): raise SystemExit("error: sshd command not found")
    result = run_capture(["sshd", "-t"])
    if result is None or result.returncode != 0:
        err = "" if result is None else result.stderr.strip()
        raise SystemExit(f"error: sshd config validation failed: {err}")

# %%
#| export
def restore_file(path: Path, previous: str | None) -> None:
    if previous is None:
        if path.exists(): path.unlink()
    else:
        path.write_text(previous)

# %%
#| export
def reload_ssh_service() -> None:
    service = ssh_service_name()
    if not cmd_exists("systemctl"): raise SystemExit("error: systemctl command not found")
    if systemctl("reload", service, check=False).returncode == 0:
        log(f"reloaded SSH service: {service}")
        return
    systemctl("restart", service)
    log(f"restarted SSH service: {service}")

# %% [markdown]
# ### SSH lockout guard
#
# `srvbox` does not change SSH ports or manage `AllowUsers`. Before disabling password login, it checks for a conservative sign that key-based access exists for the invoking sudo user or current user.

# %%
#| export
def sudo_or_login_user() -> str: return os.environ.get("SUDO_USER") or os.environ.get("USER") or "unknown"

# %%
#| export
def home_for_user(user: str) -> Path | None:
    try: return Path(pwd.getpwnam(user).pw_dir) if user != "unknown" else None
    except KeyError: return None

# %%
#| export
def authorized_keys_path(user: str) -> Path | None:
    return None if (home := home_for_user(user)) is None else home / ".ssh" / "authorized_keys"

# %%
#| export
def has_authorized_keys(user: str) -> bool:
    return False if (path := authorized_keys_path(user)) is None else bool((text := read_text(path)) and text.strip())

# %%
#| export
def require_key_auth_viable() -> None:
    user = sudo_or_login_user()
    if not has_authorized_keys(user): raise SystemExit(f"error: refusing to disable password auth; no authorized_keys found for {user}")
    log(f"key-auth viability: authorized_keys present for {user}")

# %%
#| export
def configure_ssh() -> None:
    require_key_auth_viable()
    previous = read_text(SSHD_DROPIN)
    changed = write_text_if_changed(SSHD_DROPIN, SSHD_DROPIN_TEXT)
    chown_root(SSHD_DROPIN)
    chmod(SSHD_DROPIN, 0o644)

    try:
        validate_sshd_config()
    except SystemExit:
        restore_file(SSHD_DROPIN, previous)
        validate_sshd_config()
        raise

    if changed: reload_ssh_service()
    else: log(f"SSH drop-in unchanged: {SSHD_DROPIN}")

# %% [markdown]
# ## Firewall baseline

# %% [markdown]
# `ufw` provides the host firewall baseline: deny incoming traffic, allow outgoing traffic, and allow the configured SSH port before enabling the firewall.
#
# `srvbox` does not open application ports here. App and ingress ports are added later by the relevant app or ingress layer.

# %%
#| export
SSH_DEFAULT_PORT = "22"

# %% [markdown]
# ### UFW helpers

# %% [markdown]
# These helpers keep firewall reconciliation explicit: install `ufw`, normalize the configured SSH port list, apply baseline policies, allow SSH first, and only then enable the firewall.

# %% [markdown]
# ### Apt package helper
#
# Package installation may race with `unattended-upgrades` or another apt/dpkg process. All apt operations go through a small retry helper so transient package-manager locks do not break deployments.
#
# The helper keeps retries boring: run the command, wait briefly on failure, and retry a few times before surfacing the final command failure.

# %%
#| export
APT_RETRIES = 12
APT_RETRY_SECONDS = 10

def run_apt(cmd: list[str]) -> None:
    last: subprocess.CalledProcessError | None = None
    for attempt in range(1, APT_RETRIES + 1):
        try:
            run(cmd)
            return
        except subprocess.CalledProcessError as e:
            last = e
            log(f"apt attempt {attempt}/{APT_RETRIES} failed; retrying in {APT_RETRY_SECONDS}s")
            time.sleep(APT_RETRY_SECONDS)
    raise last or SystemExit(f"error: apt command failed: {' '.join(cmd)}")

def install_packages(names: list[str]) -> None:
    run_apt(["apt-get", "update"])
    run_apt(["apt-get", "install", "-y", *names])

# %%
#| export
def ufw(*args: str, check: bool = True) -> subprocess.CompletedProcess[str]:
    return run(["ufw", *args], check=check)

# %%
#| export
def known_ssh_ports() -> list[str]:
    ports = configured_ssh_ports()
    if ports == "unknown": raise SystemExit("error: refusing to enable firewall; SSH port is unknown")
    return [port.strip() for port in ports.split(",") if port.strip()] or [SSH_DEFAULT_PORT]

# %%
# duplicate removed; canonical ufw_status lives in package and daemon status probes

# %%
#| export
def configure_firewall() -> None:
    install_packages(["ufw"])
    if not cmd_exists("ufw"): raise SystemExit("error: ufw command not found after install")

    ports = known_ssh_ports()
    log(f"firewall SSH port(s): {', '.join(ports)}")

    ufw("default", "deny", "incoming")
    ufw("default", "allow", "outgoing")

    for port in ports:
        ufw("allow", f"{port}/tcp")
        log(f"firewall allowed SSH: {port}/tcp")

    if "Status: active" in ufw_status():
        log("ufw already active")
    else:
        log("enabling ufw after SSH allow rule")
        ufw("--force", "enable")

    log("ufw status:")
    print(ufw_status(verbose=True))

# %% [markdown]
# ## fail2ban baseline
#
# `fail2ban` is installed and configured by `srvbox`, but enforcement is controlled by one explicit policy constant.
#
# During initial MVP ingress work, fail2ban remains configured but inactive so Caddy/domain/TLS bootstrap cannot be disrupted by accidental bans. Once ingress is stable, the same managed config can be enabled by flipping the policy constant.

# %%
#| export
ENABLE_FAIL2BAN = False
FAIL2BAN_JAIL = Path("/etc/fail2ban/jail.d/90-1iis-srvbox.local")

# %% [markdown]
# ### fail2ban SSH jail
#
# The managed jail protects SSH with conservative defaults and does not modify upstream fail2ban files. Non-SSH jails are left unmanaged.

# %%
#| export
def fail2ban_jail_text() -> str:
    enabled = "true" if ENABLE_FAIL2BAN else "false"
    return f"""\
# Managed by srvbox. Local changes may be overwritten.

[sshd]
enabled = {enabled}
backend = systemd
maxretry = 5
findtime = 10m
bantime = 1h
"""

# %% [markdown]
# ### fail2ban service helpers
#
# The service policy is explicit: when enabled, fail2ban is started and enabled at boot; when disabled, the config remains present but the service is stopped and disabled.

# %%
#| export
def fail2ban_active_jails() -> str:
    result = run_capture(["fail2ban-client", "status"])
    if result is None or result.returncode != 0: return "unknown"
    for line in result.stdout.splitlines():
        if "Jail list:" in line: return line.split(":", 1)[1].strip() or "none"
    return "none"

# %%
#| export
def enable_service(name: str) -> None: systemctl("enable", "--now", name)

# %%
#| export
def disable_service(name: str) -> None: systemctl("disable", "--now", name, check=False)

# %%
#| export
def configure_fail2ban() -> None:
    install_packages(["fail2ban"])
    if not cmd_exists("fail2ban-client"): raise SystemExit("error: fail2ban-client not found after install")

    changed = write_text_if_changed(FAIL2BAN_JAIL, fail2ban_jail_text())
    chown_root(FAIL2BAN_JAIL)
    chmod(FAIL2BAN_JAIL, 0o644)

    if ENABLE_FAIL2BAN:
        if changed and service_is_active("fail2ban") == "yes": systemctl("restart", "fail2ban")
        enable_service("fail2ban")
        log(f"fail2ban active jails: {fail2ban_active_jails()}")
    else:
        disable_service("fail2ban")
        log("fail2ban configured but intentionally inactive")

# %% [markdown]
# ## Unattended security upgrades

# %% [markdown]
# `unattended-upgrades` keeps Ubuntu/Debian security updates flowing without turning srvbox into a package-management framework. The reconciler ensures the package exists, enables the standard apt timers, writes the minimal periodic config, and leaves automatic reboot policy unmanaged by default.

# %%
#| export
APT_AUTO_UPGRADES = Path("/etc/apt/apt.conf.d/20auto-upgrades")
APT_AUTO_UPGRADES_TEXT = """\
APT::Periodic::Update-Package-Lists "1";
APT::Periodic::Unattended-Upgrade "1";
"""

# %%
#| export
def configure_unattended_upgrades() -> None:
    install_packages(["unattended-upgrades"])
    if not cmd_exists("unattended-upgrade"): raise SystemExit("error: unattended-upgrade not found after install")

    changed = write_text_if_changed(APT_AUTO_UPGRADES, APT_AUTO_UPGRADES_TEXT)
    chown_root(APT_AUTO_UPGRADES)
    chmod(APT_AUTO_UPGRADES, 0o644)

    enable_service("apt-daily.timer")
    enable_service("apt-daily-upgrade.timer")
    log(f"unattended upgrades periodic config: {'updated' if changed else 'unchanged'}")
    log("unattended upgrades automatic reboot: unmanaged/disabled by default")

# %% [markdown]
# ## Caddy ingress
#
# Caddy is the optional-but-first-class HTTP ingress layer for `srvbox`.
#
# When ingress is enabled, `srvbox` owns Caddy as host substrate: it installs the package, owns the global config, prepares the app fragment directory, opens HTTP/HTTPS in `ufw`, validates config before service changes, and enables the service.
#
# When ingress is disabled, vanilla `srvbox` keeps the host closed by disabling Caddy if present and removing the baseline HTTP/HTTPS firewall openings. Apps or higher infra opt into ingress explicitly instead of inheriting public web exposure by accident.

# %%
#| export
ENABLE_CADDY = True
CADDYFILE = Path("/etc/caddy/Caddyfile")
CADDY_SITES = Path("/etc/caddy/sites.d")

# %% [markdown]
# ### Caddy apt repository
#
# Caddy is installed from its official stable Debian/Ubuntu repository. The repo setup follows Caddy’s documented package recipe: install apt HTTPS/keyring prerequisites, install the stable archive keyring, install the stable apt source list, then install the `caddy` package.
#
# Installing the package may auto-start Caddy; `srvbox` immediately converges the service afterward through its own policy and managed config.

# %%
#| export
CADDY_KEYRING = Path("/usr/share/keyrings/caddy-stable-archive-keyring.gpg")
CADDY_APT_SOURCE = Path("/etc/apt/sources.list.d/caddy-stable.list")
CADDY_GPG_URL = "https://dl.cloudsmith.io/public/caddy/stable/gpg.key"
CADDY_DEB_URL = "https://dl.cloudsmith.io/public/caddy/stable/debian.deb.txt"

# %%
#| export
def install_url(url: str, path: Path, *, dearmor: bool = False) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    if dearmor:
        run(["sh", "-c", f"curl -1sLf {url!r} | gpg --dearmor -o {str(path)!r}"])
    else:
        run(["sh", "-c", f"curl -1sLf {url!r} > {str(path)!r}"])
    chmod(path, 0o644)

# %%
#| export
def ensure_caddy_repo() -> None:
    install_packages(["debian-keyring", "debian-archive-keyring", "apt-transport-https", "curl", "gpg"])
    if not CADDY_KEYRING.exists(): install_url(CADDY_GPG_URL, CADDY_KEYRING, dearmor=True)
    if not CADDY_APT_SOURCE.exists(): install_url(CADDY_DEB_URL, CADDY_APT_SOURCE)
    run_apt(["apt-get", "update"])

# %% [markdown]
# ### Caddy global config
#
# The global Caddyfile is intentionally minimal. It defines the managed root config and imports app/site fragments, but contains no domain names, app routes, or reverse proxies.
#
# App deploys own their fragments under `/etc/caddy/sites.d/*.caddy`.

# %%
#| export
def caddyfile_text() -> str:
    return """\
# Managed by srvbox. Local changes may be overwritten.

import /etc/caddy/sites.d/*.caddy
"""

# %% [markdown]
# ### Caddy service helpers
#
# Caddy config is validated before reload/start. If a managed config write produces an invalid effective config, the previous Caddyfile is restored before failing.

# %%
#| export
def caddy(*args: str, check: bool = True) -> subprocess.CompletedProcess[str]:
    return run(["caddy", *args], check=check)

# %%
#| export
def validate_caddy_config() -> None:
    if not cmd_exists("caddy"): raise SystemExit("error: caddy command not found")
    result = run_capture(["caddy", "validate", "--config", str(CADDYFILE)])
    if result is None or result.returncode != 0:
        err = "" if result is None else (result.stderr.strip() or result.stdout.strip())
        raise SystemExit(f"error: caddy config validation failed: {err}")

# %%
#| export
def reload_or_start_caddy(changed: bool) -> None:
    if service_is_active("caddy") == "yes" and changed:
        systemctl("reload", "caddy")
        log("reloaded Caddy")
    else:
        enable_service("caddy")
        log("enabled/started Caddy")

# %% [markdown]
# ### Caddy reconciliation
#
# The Caddy step is policy-controlled. Disabled ingress means the public web surface is closed by default: Caddy is stopped if active, and the baseline HTTP/HTTPS `ufw` openings are removed.
#
# Enabled ingress installs Caddy, prepares the fragment directory, writes and validates the global config, enables the service, and opens HTTP/HTTPS.
#
# `fail2ban` remains intentionally inactive during early Caddy/domain/TLS bootstrap. It should be enabled only after certificate issuance and routing are stable.

# %%
#| export
def configure_caddy() -> None:
    if not ENABLE_CADDY:
        ufw("delete", "allow", "80/tcp", check=False)
        ufw("delete", "allow", "443/tcp", check=False)
        if cmd_exists("systemctl") and service_is_active("caddy") == "yes": disable_service("caddy")
        log("Caddy ingress disabled by policy")
        return

    ensure_caddy_repo()
    install_packages(["caddy"])
    if not cmd_exists("caddy"): raise SystemExit("error: caddy command not found after install")

    CADDY_SITES.mkdir(parents=True, exist_ok=True)
    chown_root(CADDY_SITES)
    chmod(CADDY_SITES, 0o755)

    previous = read_text(CADDYFILE)
    changed = write_text_if_changed(CADDYFILE, caddyfile_text())
    chown_root(CADDYFILE)
    chmod(CADDYFILE, 0o644)

    try:
        validate_caddy_config()
    except SystemExit:
        restore_file(CADDYFILE, previous)
        validate_caddy_config()
        raise

    ufw("allow", "80/tcp")
    ufw("allow", "443/tcp")
    reload_or_start_caddy(changed)

# %% [markdown]
# ## Read-only command and filesystem helpers

# %% [markdown]
# Step 2.1 makes `status` a non-mutating hardening dashboard.
#
# These helpers are deliberately boring: stdlib-only, non-root-compatible, graceful on missing files/commands/services, and local to `host/sync.py`.

# %%
#| export
def yesno(value: bool) -> str: return "yes" if value else "no"

# %%
#| export
def cmd_path(name: str) -> str: return shutil.which(name) or "missing"

# %%
#| export
def cmd_exists(name: str) -> bool: return cmd_path(name) != "missing"

# %%
#| export
def run_capture(cmd: list[str], *, check: bool = False) -> subprocess.CompletedProcess[str] | None:
    try: return subprocess.run(cmd, check=check, text=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    except FileNotFoundError: return None

# %%
#| export
def read_text(path: Path) -> str | None:
    try: return path.read_text()
    except (FileNotFoundError, PermissionError, IsADirectoryError, OSError): return None

# %%
#| export
def file_exists(path: Path) -> bool: return path.is_file()

# %%
#| export
def dir_exists(path: Path) -> bool: return path.is_dir()

# %% [markdown]
# ## OS and service probes

# %% [markdown]
# `status` should degrade gracefully outside the final server shape: local dev machines, non-root shells, missing packages, and minimal VMs are all normal cases.

# %%
#| export
def os_release_summary() -> str:
    data = read_text(Path("/etc/os-release"))
    if data is None: return "unknown"
    fields = dict(line.split("=", 1) for line in data.splitlines() if "=" in line and not line.startswith("#"))
    fields = {k: v.strip().strip('"') for k,v in fields.items()}
    return fields.get("PRETTY_NAME") or " ".join(x for x in [fields.get("NAME"), fields.get("VERSION")] if x) or "unknown"

# %%
#| export
def service_is_active(name: str) -> str:
    return "unknown" if not cmd_exists("systemctl") or (r := run_capture(["systemctl", "is-active", "--quiet", name])) is None else yesno(r.returncode == 0)

# %%
#| export
def service_is_enabled(name: str) -> str:
    return "unknown" if not cmd_exists("systemctl") or (r := run_capture(["systemctl", "is-enabled", "--quiet", name])) is None else yesno(r.returncode == 0)

# %% [markdown]
# ## SSH status probes

# %% [markdown]
# Phase 2 SSH hardening depends on knowing whether OpenSSH config exists, whether drop-ins are included, and which port is configured.
#
# For Step 2.1, inspect only readable config files. No `sshd -T` dependency yet.

# %%
#| export
def sshd_config_path() -> Path: return Path("/etc/ssh/sshd_config")

# %%
#| export
def sshd_config_d_path() -> Path: return Path("/etc/ssh/sshd_config.d")

# %%
#| export
def active_config_lines(text: str) -> list[str]:
    return [line for raw in text.splitlines() if (line := raw.strip()) and not line.startswith("#")]

# %%
#| export
def sshd_config_includes_dropins() -> str:
    text = read_text(sshd_config_path())
    if text is None: return "unknown"
    includes = [" ".join(parts[1:]) for line in active_config_lines(text) if len(parts := line.split()) >= 2 and parts[0].lower() == "include"]
    return yesno(any("sshd_config.d" in include and "*.conf" in include for include in includes))

# %%
#| export
def configured_ssh_ports() -> str:
    paths = [sshd_config_path()] + (sorted(sshd_config_d_path().glob("*.conf")) if sshd_config_d_path().is_dir() else [])
    texts = [text for path in paths if (text := read_text(path)) is not None]
    ports = [parts[1] for text in texts for line in active_config_lines(text) if len(parts := line.split()) >= 2 and parts[0].lower() == "port"]
    if ports: return ", ".join(dict.fromkeys(ports))
    if texts: return "22"
    return "unknown"

# %% [markdown]
# ## Package and daemon status probes

# %% [markdown]
# These probes report whether Phase 2 components appear present. They must not install, enable, reload, restart, or write anything.

# %%
#| export
def ufw_status(verbose: bool = False) -> str:
    args = ["ufw", "status", "verbose"] if verbose else ["ufw", "status"]
    if not cmd_exists("ufw") or (r := run_capture(args)) is None or r.returncode != 0: return "unknown"
    return r.stdout.strip() or "unknown"

# %%
#| export
def unattended_upgrades_status() -> str:
    binary   = cmd_exists("unattended-upgrade")
    config   = file_exists(Path("/etc/apt/apt.conf.d/50unattended-upgrades"))
    periodic = file_exists(Path("/etc/apt/apt.conf.d/20auto-upgrades"))
    return f"binary={yesno(binary)}, config={yesno(config)}, periodic={yesno(periodic)}, timer_active={service_is_active('apt-daily-upgrade.timer')}"

# %% [markdown]
# ## Status command

# %% [markdown]
# `status` is the read-only host dashboard. It reports enough system, SSH, firewall, fail2ban, and unattended-upgrades facts to diagnose the baseline before or after running `apply`.

# %%
#| export
def check_status() -> None:
    facts = [
        ("repo root",                         ROOT),
        ("python",                            sys.version.split()[0]),
        ("platform",                          platform.platform()),
        ("euid",                              os.geteuid()),
        ("root",                              yesno(os.geteuid() == 0)),
        ("os",                                os_release_summary()),

        ("apt-get",                           cmd_path("apt-get")),
        ("systemctl",                         cmd_path("systemctl")),

        ("ssh",                               cmd_path("ssh")),
        ("sshd",                              cmd_path("sshd")),
        ("ssh service active",                service_is_active("ssh")),
        ("ssh service enabled",               service_is_enabled("ssh")),
        ("sshd_config",                       yesno(file_exists(sshd_config_path()))),
        ("sshd_config.d",                     yesno(dir_exists(sshd_config_d_path()))),
        ("sshd_config includes drop-ins",     sshd_config_includes_dropins()),
        ("ssh ports",                         configured_ssh_ports()),

        ("ufw",                               cmd_path("ufw")),
        ("ufw status",                        ufw_status()),

        ("fail2ban policy enabled",            yesno(ENABLE_FAIL2BAN)),
        ("fail2ban-client",                   cmd_path("fail2ban-client")),
        ("fail2ban active",                   service_is_active("fail2ban")),
        ("fail2ban enabled",                  service_is_enabled("fail2ban")),
        ("fail2ban managed jail",             yesno(file_exists(FAIL2BAN_JAIL))),
        ("fail2ban active jails",             fail2ban_active_jails() if service_is_active("fail2ban") == "yes" else "inactive"),

        ("unattended-upgrade",                cmd_path("unattended-upgrade")),
        ("unattended-upgrades",               unattended_upgrades_status()),

        ("caddy policy enabled",              yesno(ENABLE_CADDY)),
        ("caddy",                             cmd_path("caddy")),
        ("caddy active",                      service_is_active("caddy")),
        ("caddy enabled",                     service_is_enabled("caddy")),
        ("caddyfile",                         yesno(file_exists(CADDYFILE))),
        ("caddy sites.d",                     yesno(dir_exists(CADDY_SITES))),
    ]
    for key, value in facts: log(f"{key}: {value}")
    log("status check complete")

# %% [markdown]
# ## Apply command

# %% [markdown]
# `apply` is the mutating path. It first checks guard rails, then runs steps in the deliberately boring order: base filesystem shape, identity, access hardening, rate limiting, unattended security updates, and optional ingress.

# %%
#| export
STEPS = [
    Step("base directories", ensure_base_dirs),
    Step("access policy", check_access_policy),
    Step("ssh hardening", configure_ssh),
    Step("firewall", configure_firewall),
    Step("fail2ban", configure_fail2ban),
    Step("unattended upgrades", configure_unattended_upgrades),
    Step("caddy", configure_caddy),
]

# %%
#| export
def apply() -> None:
    require_root()
    require_ubuntuish()

    for step in STEPS:
        log(f"Step: {step.name}")
        step.fn()

# %% [markdown]
# ## CLI

# %% [markdown]
# The command-line interface is intentionally tiny: `status` for safe observation, `apply` for reconciliation. Keeping the public surface this small helps the shell bootstrap stay stable.

# %%
#| export
def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(description="srvbox host reconciler")
    parser.add_argument(
        "command",
        choices=["status", "apply"],
        help="status checks the host; apply reconciles desired state",
    )
    return parser.parse_args()

# %%
#| export
def main() -> None:
    args = parse_args()

    if args.command == "status":
        check_status()
    elif args.command == "apply":
        apply()
    else:
        raise SystemExit(f"unknown command: {args.command}")

# %%
#| export
if __name__ == "__main__":
    main()
